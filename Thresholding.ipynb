# %% [markdown]
# #Thresholding based on different image sets

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import imageio.v3 as iio
import skimage.color
import skimage.filters
# %matplotlib inline

# %% [markdown]
# ##WORKING ON NORMAL IMAGE

# %%
image = iio.imread(uri="crack4.jpg")

fig, ax = plt.subplots()
plt.imshow(image)

# %%
# blur the image to denoise
blurred_image = skimage.filters.gaussian(image, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")

# %%
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))

fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0, 1.0)
# Out:
# (0.0, 1.0)

# %%
t = 0.5
binary_mask = blurred_image < t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap="gray")

# %% [markdown]
# WORKING ON A MORE CONTRAST IMAGE

# %%
image = iio.imread(uri="more-contrast-image.png")

fig, ax = plt.subplots()
plt.imshow(image)

# %%
# blur the image to denoise
blurred_image = skimage.filters.gaussian(image, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")

# %%
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))

fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0, 1.0)
# Out:
# (0.0, 1.0)

# %%
t = 0.4
binary_mask = blurred_image < t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap="gray")
